# %%
import utils
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import numpy as np
# %matplotlib inline

# %%
image = mpimg.imread('test_images/test1.jpg')

bboxes = [((100, 100), (200, 200)), ((300, 300), (400, 400))]
result = utils.draw_boxes(image, bboxes)
plt.imshow(result)

# %%
templist = ['test_matches/i1.png', 'test_matches/i2.png', 'test_matches/i3.png',
            'test_matches/i4.png', 'test_matches/i5.png']

bboxes = utils.find_matches(image, templist)
result = utils.draw_boxes(image, bboxes)
plt.imshow(result)

# %%
image = mpimg.imread('test_matches/i1.png')

rh, gh, bh, bincen, feature_vec = utils.color_hist(image, nbins=32, bins_range=(0, 256))

# Plot a figure with all three bar charts
if rh is not None:
    fig = plt.figure(figsize=(12,3))
    plt.subplot(131)
    plt.bar(bincen, rh[0])
    plt.xlim(0, 256)
    plt.title('R Histogram')
    plt.subplot(132)
    plt.bar(bincen, gh[0])
    plt.xlim(0, 256)
    plt.title('G Histogram')
    plt.subplot(133)
    plt.bar(bincen, bh[0])
    plt.xlim(0, 256)
    plt.title('B Histogram')
    fig.tight_layout()
else:
    print('Your function is returning None for at least one variable...')

# %%
# Read in an image
# You can also read cutout2, 3, 4 etc. to see other examples
image = mpimg.imread('cutout1.jpg')
    
feature_vec = utils.bin_spatial(image, color_space='RGB', size=(32, 32))

# Plot features
plt.plot(feature_vec)
plt.title('Spatially Binned Features')

# %%
images = glob.glob('*.jpeg')
cars = []
notcars = []

for image in images:
    if 'image' in image or 'extra' in image:
        notcars.append(image)
    else:
        cars.append(image)
    
data_info = utils.data_look(cars, notcars)

print('Your function returned a count of', 
      data_info["n_cars"], ' cars and', 
      data_info["n_notcars"], ' non-cars')
print('of size: ',data_info["image_shape"], ' and data type:', 
      data_info["data_type"])
# Just for fun choose random car / not-car indices and plot example images   
car_ind = np.random.randint(0, len(cars))
notcar_ind = np.random.randint(0, len(notcars))
    
# Read in car / not-car images
car_image = mpimg.imread(cars[car_ind])
notcar_image = mpimg.imread(notcars[notcar_ind])


# Plot the examples
fig = plt.figure()
plt.subplot(121)
plt.imshow(car_image)
plt.title('Example Car Image')
plt.subplot(122)
plt.imshow(notcar_image)
plt.title('Example Not-car Image')

# %%
#TODO: 20. scikit-image HOG
